# %% [markdown]
# # Data visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
sales_data = pd.read_csv("SampleSuperstore.csv")  # Update with your CSV filename
product_sales = sales_data.groupby(['Category', 'Region'])['Quantity'].sum().reset_index()
top_selling_products = product_sales.groupby('Region').apply(lambda x: x.nlargest(1, 'Quantity'))
plt.figure(figsize=(12, 8))
for region, data in top_selling_products.groupby(level=0):
    plt.bar(data['Category'], data['Quantity'], label=region)
plt.xlabel('PRODUCT')
plt.ylabel('QUANTITY')
plt.title('TOP SELLING PRODUCT IN DIFFERENT REGION ')
plt.legend()
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
sales_data = pd.read_csv("SampleSuperstore.csv")  
sales_data['SalesDate'] = pd.to_datetime(sales_data['SalesDate'])
sales_data['Month'] = sales_data['SalesDate'].dt.month
def get_season(month):
    if month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Fall'
    else:
        return 'Winter'
sales_data['Season'] = sales_data['Month'].apply(get_season)
seasonal_sales = sales_data.groupby('Season')['Quantity'].sum()
plt.figure(figsize=(10, 6))
seasonal_sales.plot(marker='o', color='b', linestyle='-')
plt.title('Sales Variation by Season')
plt.xlabel('Season')
plt.ylabel('Total Sales Quantity')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Gowtham\AppData\Local\Temp\ipykernel_14432\654133001.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sales_data['SalesDate'] = pd.to_datetime(sales_data['SalesDate'])
